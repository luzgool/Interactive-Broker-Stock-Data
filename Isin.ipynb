# %%
import pandas as pd
import numpy as np
import io
import requests
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', 100)
base = pd.read_excel('LIst of 19.7 Stocks with FIGI if available - By Evelyn.xlsx')

# %%
base.head(10)
# Out:
#    Unnamed: 0 symbol_x                      longName     Exchange  \
# 0           0      1ST                 1ST GROUP LTD          ASX
# 1           1     TWOU                        2U INC       NASDAQ
# 2           2     DDDX            3DX INDUSTRIES INC         PINK
# 3           3      MMM                         3M CO  US Exchange
# 4           4      88E                 88 ENERGY LTD          LSE
# 5           5     AQFD           A CLASSIFIED AD INC        VALUE
# 6           6     7063                  A DOT CO LTD         TSEJ
# 7           7    AMKBY  A P MOLLER-MAERSK-B-UNSP ADR         PINK
# 8           8    MLATV           A TOUTE VITESSE-ATV          SBF
# 9           9     AMRK    A-MARK PRECIOUS METALS INC       NASDAQ
#
#                     Country                   country           name  \
# 0                 Australia                 australia            NaN
# 1  United States of America  united states of america            NaN
# ...

# %%
len(base)
# Out:
# 19736

# %%
lst = remain['symbol_x']
# Out:
# 8      MLATV
# 26      ABKI
# 53      APEF
# 73      ABRL
# 74       L5I
#        ...
# 926     AMP2
# 949      ANQ
# 962    ANCJQ
# 963     ANCN
# 964     AHCP
# Name: symbol_x, Length: 100, dtype: object

# %%
df = pd.DataFrame()
for ticker in x:
    lst = []
    url = 'https://eodhistoricaldata.com/api/search/' + ticker + '?api_token=5f3afd582bd7b4.95720069'
    source =requests.get(url).content
    extract_df = pd.read_json(source)
    extract_df['Ticker'] = ticker
    l = e.iloc[0:1]
    k = pd.concat([l])
    df = df.append(k)

# %%
df.to_csv("isin_19k.csv")
# Out:
# Empty DataFrame
# Columns: [Ticker]
# Index: []

# %%
isin1.head(10)
# Out:
#    Unnamed: 0          longName_x        isin_y
# 0           0       1ST GROUP LTD           NaN
# 1           1              2U INC  US90214J1016
# 2           2  3DX INDUSTRIES INC           NaN
# 3           3               3M CO  ARDEUT110293
# 4           4               3M CO  CA6025321036
# 5           5               3M CO  US88579Y1010
# 6           6               3M CO  US88579Y1010
# 7           7               3M CO  US88579Y1010
# 8           8               3M CO  US88579Y1010
# 9           9       88 ENERGY LTD  AU00000088E2

# %%
len(base)
# Out:
# 19736

# %%
stock_list = base['longName'].to_list()
stock_list
# Out:
# ['1ST GROUP LTD',
#  '2U INC',
#  '3DX INDUSTRIES INC',
#  '3M CO',
#  '88 ENERGY LTD',
#  'A CLASSIFIED AD INC',
#  'A DOT CO LTD',
#  'A P MOLLER-MAERSK-B-UNSP ADR',
#  'A TOUTE VITESSE-ATV',
#  'A-MARK PRECIOUS METALS INC',
#  'A-TEC INDUSTRIES AG',
#  'AA GROUP HOLDINGS LTD',
#  'AAC HOLDINGS INC',
#  'AAC TECHNOLOGIES HOLDINGS IN',
#  'AAG ENERGY HOLDINGS LTD',
#  'AAON INC',
#  'AAREAL BANK AG-UNSPON ADR',
#  'AARON INDUSTRIES LTD',
#  "AARON'S INC",
#  'AARTI DRUGS LIMITED',
#  'AARTI INDUSTRIES LIMITED',
#  'AAVAS FINANCIERS LTD',
#  'AB DYNAMICS PLC',
#  'AB INTERNATIONAL GROUP CORP',
#  'AB&T FINANCIAL CORP',
#  'ABACUS PROPERTY GROUP',
#  'ABAKAN INC',
#  'ABAN OFFSHORE LIMITED',
#  'ABATTIS BIOCEUTICALS CORP',
#  'ABAXIS INC',
#  'ABB INDIA LTD',
#  'ABB INDIA LTD',
#  'ABBA MEDIX GROUP INC',
#  'ABBEY PLC',
#  'ABBOTT INDIA LTD',
#  'ABBOTT LABORATORIES',
#  'ABBVIE INC',
#  'ABBY INC',
#  'ABC-MART INC',
#  'ABCO ENERGY INC',
#  'ABCOURT MINES INC -CL B',
# ...
